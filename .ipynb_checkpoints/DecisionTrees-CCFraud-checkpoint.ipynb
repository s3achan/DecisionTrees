# %%
import pandas as pd

def calculate_gini_impurity(target_series):
    """
    Calculates the Gini impurity for a given target variable Series.
    """
    # Get the counts of each class in the target series
    counts = target_series.value_counts()
    total_count = len(target_series)

    if total_count == 0:
        return 0.0 # Impurity is 0 if there are no samples

    gini = 1.0
    for count in counts:
        proportion = count / total_count
        gini -= proportion**2
    return gini
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 def calculate_gini_impurity(target_series):
#       4     """
#       5     Calculates the Gini impurity for a given target variable Series.
#       6     """
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# value = 5 no, 9 yes
# samples = 14
# 1 - (0.64² + 0.36²) ≈ 0.459

# %%
a = 5/14
a
# Out:
# 0.35714285714285715

# %%
b = 9/14
b
# Out:
# 0.6428571428571429

# %%
1 - (a**2 + b**2)
# Out:
# 0.4591836734693877
